# %% [markdown]
# # Workshop: Predictive Analytics mit Python

# %% [markdown]
# ## Short Introduction to Python

# %%
# You may use Python as calculator:
2 + 3
# Click Shift+Enter to execute
# Out:
# 5

# %%
# Another primitive type apart from Number is a String
str = 'Hello'
str
# Out:
# 'Hello'

# %%
# indexing may be used to get one character of a string
str[0]
# Out:
# 'H'

# %%
# you may concatenate strings
str + ' World'
# Out:
# 'Hello World'

# %%
# lists are mutable collections
list = [1,2,3,4,5]
# the numbers in the case are integers of type int32
list
# Out:
# [1, 2, 3, 4, 5]

# %%
# indexing may be used to get one element of a list
list[0]
# also try negative index to get element from the tail of the list
# Out:
# 1

# %%
# indexing may also be used to get multiple elements
list[2:4]
# Out:
# [3, 4]

# %%
# get the length of the collection
len(list)
# Out:
# 5

# %%
# mutability means you may change the values
list[2] = 'a'
list
# be aware that lists of different subtypes in most cases don't make sense
# Out:
# [1, 2, 'a', 4, 5]

# %%
# in most cases we want to avoid mutability because it leaves room for error
# tuples are immutable collections, prefer them over lists
tuple = (1,2,3,4,5)
tuple
# Out:
# (1, 2, 3, 4, 5)

# %%
# use a dictionary if you want to use keys instead of indices
dict = {'key': 'value', 'hello': 'world'}
dict
# keys must be unique
# Out:
# {'key': 'value', 'hello': 'world'}

# %%
# use dicts whenever you need a named key
dict['hello']
# Out:
# 'world'

# %%
# you may use conditional statements
x = 5
if (x % 2 == 0):
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# See https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html for an introduction to Pandas.

# %%
# we need to import the libraries before we may use them
# if an ImportError is thrown, you need to install the libraries via pip3
import numpy as np
import pandas as pd
# both are now accessible using np respectively pd before the function name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-29908e3de186> in <module>
#       2 # if an ImportError is thrown, you need to install the libraries via pip3
#       3 import numpy as np
# ----> 4 import pandas as pd
#       5 # both are now accessible using np respectively pd before the function name
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# We need to import and clean the data before we may explore it.
# We use the dataset from https://www.kaggle.com/rhuebner/human-resources-data-set.

# %%
df = pd.read_csv('HRDataset_v13.csv', nrows=310, index_col='EmpID')
# we use index_col=EmpID to use the date as index and not the line number
# we use nrows=310 to avoid the empty lines at the bottom of the file

# Pandas uses DataFrame which is like a spreadsheet table
df
# Out:
#                      Employee_Name  MarriedID  MaritalStatusID  GenderID  \
# EmpID
# 1103024456              Brown, Mia          1                1         0
# 1106026572    LaRotonda, William            0                2         1
# 1302053333        Steans, Tyrone            0                0         1
# 1211050782         Howard, Estelle          1                1         0
# 1307059817             Singh, Nan           0                0         0
# ...                            ...        ...              ...       ...
# 1411071312          Daniele, Ann            1                1         0
# 1108028108          Lajiri,  Jyoti          1                1         1
# 904013591   Semizoglou, Jeremiah            1                1         1
# 1308060959              South, Joe          0                0         1
# 1301052347         Warfield, Sarah          0                4         0
#
#             EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  \
# EmpID
# 1103024456            1       1            3                       1    28.50
# 1106026572            1       1            3                       0    23.00
# 1302053333            1       1            3                       0    29.00
# 1211050782            1       1            3                       0    21.50
# 1307059817            1       1            3                       0    16.56
# ...                 ...     ...          ...                     ...      ...
# 1411071312            3       3            3                       0    54.10
# 1108028108            3       3            3                       0    56.20
# 904013591             2       3            3                       0    53.80
# 1308060959            1       3            3                       0    53.00
# 1301052347            1       3            3                       0    55.20
#
#             Termd  ...     Department         ManagerName ManagerID  \
# EmpID              ...
# 1103024456      0  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 1106026572      0  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 1302053333      0  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 1211050782      1  ...  Admin Offices  Brandon R. LeBlanc       1.0
# 1307059817      0  ...  Admin Offices  Brandon R. LeBlanc       1.0
# ...           ...  ...            ...                 ...       ...
# 1411071312      0  ...          IT/IS        Peter Monroe       7.0
# 1108028108      0  ...          IT/IS        Peter Monroe       7.0
# 904013591       0  ...          IT/IS        Peter Monroe       7.0
# 1308060959      0  ...          IT/IS        Peter Monroe       7.0
# 1301052347      0  ...          IT/IS        Peter Monroe       7.0
#
#                  RecruitmentSource PerformanceScore EngagementSurvey  \
# EmpID
# 1103024456      Diversity Job Fair      Fully Meets             2.04
# 1106026572      Website Banner Ads      Fully Meets             5.00
# 1302053333         Internet Search      Fully Meets             3.90
# 1211050782  Pay Per Click - Google      Fully Meets             3.24
# 1307059817      Website Banner Ads      Fully Meets             5.00
# ...                            ...              ...              ...
# 1411071312         Vendor Referral      Fully Meets             1.55
# 1108028108       Employee Referral      Fully Meets             4.46
# 904013591     On-campus Recruiting      Fully Meets             3.27
# 1308060959       Employee Referral      Fully Meets             5.00
# 1301052347       Employee Referral      Fully Meets             1.06
#
#            EmpSatisfaction SpecialProjectsCount LastPerformanceReview_Date  \
# EmpID
# 1103024456               2                    6                  1/15/2019
# 1106026572               4                    4                  1/17/2019
# 1302053333               5                    5                  1/18/2019
# 1211050782               3                    4                        NaN
# 1307059817               3                    5                  1/15/2019
# ...                    ...                  ...                        ...
# 1411071312               5                    8                  2/12/2019
# 1108028108               5                    6                   1/7/2019
# 904013591                4                    5                  1/14/2019
# 1308060959               3                    4                   1/2/2019
# 1301052347               4                    8                   2/5/2019
#
#            DaysLateLast30
# EmpID
# 1103024456            0.0
# 1106026572            0.0
# 1302053333            0.0
# 1211050782            NaN
# 1307059817            0.0
# ...                   ...
# 1411071312            0.0
# 1108028108            0.0
# 904013591             0.0
# 1308060959            0.0
# 1301052347            0.0
#
# [310 rows x 34 columns]

# %%
# we can get basic metrics of numerical columns to understand the data
df.describe()
# Out:
#         MarriedID  MaritalStatusID    GenderID  EmpStatusID      DeptID  \
# count  310.000000       310.000000  310.000000   310.000000  310.000000
# mean     0.396774         0.809677    0.429032     2.396774    4.606452
# std      0.490019         0.944702    0.495738     1.795533    1.082349
# min      0.000000         0.000000    0.000000     1.000000    1.000000
# 25%      0.000000         0.000000    0.000000     1.000000    5.000000
# 50%      0.000000         1.000000    0.000000     1.000000    5.000000
# 75%      1.000000         1.000000    1.000000     5.000000    5.000000
# max      1.000000         4.000000    1.000000     5.000000    6.000000
#
#        PerfScoreID  FromDiversityJobFairID     PayRate       Termd  \
# count   310.000000              310.000000  310.000000  310.000000
# mean      2.983871                0.093548   31.284806    0.332258
# std       0.577124                0.291670   15.383615    0.471785
# min       1.000000                0.000000   14.000000    0.000000
# 25%       3.000000                0.000000   20.000000    0.000000
# 50%       3.000000                0.000000   24.000000    0.000000
# 75%       3.000000                0.000000   45.315000    1.000000
# max       4.000000                1.000000   80.000000    1.000000
#
#        PositionID           Zip   ManagerID  EngagementSurvey  \
# count  310.000000    310.000000  302.000000        310.000000
# mean    16.838710   6569.732258   14.579470          3.332097
# std      6.232272  16933.864054    8.090352          1.290590
# min      1.000000   1013.000000    1.000000          1.030000
# 25%     18.000000   1901.250000   10.000000          2.082500
# 50%     19.000000   2132.000000   15.000000          3.470000
# 75%     20.000000   2357.000000   19.000000          4.520000
# max     30.000000  98052.000000   39.000000          5.000000
#
#        EmpSatisfaction  SpecialProjectsCount  DaysLateLast30
# count       310.000000            310.000000           207.0
# mean          3.890323              1.209677             0.0
# std           0.910690              2.352009             0.0
# min           1.000000              0.000000             0.0
# 25%           3.000000              0.000000             0.0
# 50%           4.000000              0.000000             0.0
# 75%           5.000000              0.000000             0.0
# max           5.000000              8.000000             0.0

# %%
# 310 entries
# DaysLateLast30 is worthless, so we drop it
df = df.drop(columns='DaysLateLast30')
df.describe()
# Out:
#         MarriedID  MaritalStatusID    GenderID  EmpStatusID      DeptID  \
# count  310.000000       310.000000  310.000000   310.000000  310.000000
# mean     0.396774         0.809677    0.429032     2.396774    4.606452
# std      0.490019         0.944702    0.495738     1.795533    1.082349
# min      0.000000         0.000000    0.000000     1.000000    1.000000
# 25%      0.000000         0.000000    0.000000     1.000000    5.000000
# 50%      0.000000         1.000000    0.000000     1.000000    5.000000
# 75%      1.000000         1.000000    1.000000     5.000000    5.000000
# max      1.000000         4.000000    1.000000     5.000000    6.000000
#
#        PerfScoreID  FromDiversityJobFairID     PayRate       Termd  \
# count   310.000000              310.000000  310.000000  310.000000
# mean      2.983871                0.093548   31.284806    0.332258
# std       0.577124                0.291670   15.383615    0.471785
# min       1.000000                0.000000   14.000000    0.000000
# 25%       3.000000                0.000000   20.000000    0.000000
# 50%       3.000000                0.000000   24.000000    0.000000
# 75%       3.000000                0.000000   45.315000    1.000000
# max       4.000000                1.000000   80.000000    1.000000
#
#        PositionID           Zip   ManagerID  EngagementSurvey  \
# count  310.000000    310.000000  302.000000        310.000000
# mean    16.838710   6569.732258   14.579470          3.332097
# std      6.232272  16933.864054    8.090352          1.290590
# min      1.000000   1013.000000    1.000000          1.030000
# 25%     18.000000   1901.250000   10.000000          2.082500
# 50%     19.000000   2132.000000   15.000000          3.470000
# 75%     20.000000   2357.000000   19.000000          4.520000
# max     30.000000  98052.000000   39.000000          5.000000
#
#        EmpSatisfaction  SpecialProjectsCount
# count       310.000000            310.000000
# mean          3.890323              1.209677
# std           0.910690              2.352009
# min           1.000000              0.000000
# 25%           3.000000              0.000000
# 50%           4.000000              0.000000
# 75%           5.000000              0.000000
# max           5.000000              8.000000

# %%
# check missing values
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Employee_Name                   0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# PayRate                         0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      1
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# PerformanceScore                0
# EngagementSurvey                0
# EmpSatisfaction                 0
# SpecialProjectsCount            0
# LastPerformanceReview_Date    103
# dtype: int64

# %%
# TermReason, DateofTermination, EmpStatusID and EmploymentStatus hold information regarding termination
# we remove them because for a prediction they are not known
df = df.drop(columns=['TermReason', 'DateofTermination', 'EmpStatusID', 'EmploymentStatus'])
df.apply(lambda x: sum(x.isnull()), axis=0)
# Out:
# Employee_Name                   0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# PayRate                         0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# Department                      0
# ManagerName                     0
# ManagerID                       8
# RecruitmentSource               0
# PerformanceScore                0
# EngagementSurvey                0
# EmpSatisfaction                 0
# SpecialProjectsCount            0
# LastPerformanceReview_Date    103
# dtype: int64

# %%
# let's look at ManagerID next
df[df['ManagerID'].isnull()]
# Out:
#                  Employee_Name  MarriedID  MaritalStatusID  GenderID  DeptID  \
# EmpID
# 1110029777       Becker, Scott          0                0         1       5
# 1111030129   Chang, Donovan  E          0                0         1       5
# 1405067642     Rivera, Haley            1                1         0       5
# 807010161       Sewkumar, Nori          0                0         0       5
# 1101023457  Buccheri, Joseph            0                0         1       5
# 1402065085     Fancett, Nicole          0                0         0       5
# 1103024924     Hutter, Rosalie          0                3         0       5
# 1110029623   Manchester, Robyn          1                1         0       5
#
#             PerfScoreID  FromDiversityJobFairID  PayRate  Termd  PositionID  \
# EmpID
# 1110029777            3                       0     17.0      0          19
# 1111030129            3                       0     22.0      0          19
# 1405067642            4                       0     22.0      0          19
# 807010161             3                       0     15.2      0          19
# 1101023457            3                       0     22.0      0          20
# 1402065085            3                       0     24.0      0          20
# 1103024924            3                       0     28.0      0          20
# 1110029623            3                       0     23.0      0          20
#
#             ...  DateofHire         Department     ManagerName ManagerID  \
# EmpID       ...
# 1110029777  ...    7/8/2013  Production         Webster Butler       NaN
# 1111030129  ...    7/8/2013  Production         Webster Butler       NaN
# 1405067642  ...  11/28/2011  Production         Webster Butler       NaN
# 807010161   ...   9/30/2013  Production         Webster Butler       NaN
# 1101023457  ...   9/29/2014  Production         Webster Butler       NaN
# 1402065085  ...   2/17/2014  Production         Webster Butler       NaN
# 1103024924  ...    6/5/2015  Production         Webster Butler       NaN
# 1110029623  ...   5/11/2016  Production         Webster Butler       NaN
#
#                             RecruitmentSource PerformanceScore  \
# EmpID
# 1110029777                           MBTA ads      Fully Meets
# 1111030129                 Newspager/Magazine      Fully Meets
# 1405067642  Search Engine - Google Bing Yahoo          Exceeds
# 807010161   Search Engine - Google Bing Yahoo      Fully Meets
# 1101023457                      Word of Mouth      Fully Meets
# 1402065085                 Newspager/Magazine      Fully Meets
# 1103024924                              Other      Fully Meets
# 1110029623                    Vendor Referral      Fully Meets
#
#            EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# EmpID
# 1110029777             1.09               4                    0
# 1111030129             3.80               5                    0
# 1405067642             4.36               5                    0
# 807010161              5.00               5                    0
# 1101023457             3.19               3                    0
# 1402065085             4.00               4                    0
# 1103024924             2.63               3                    0
# 1110029623             5.00               3                    0
#
#            LastPerformanceReview_Date
# EmpID
# 1110029777                  1/11/2019
# 1111030129                  1/14/2019
# 1405067642                  2/11/2019
# 807010161                   2/21/2019
# 1101023457                   2/1/2019
# 1402065085                   1/7/2019
# 1103024924                  2/14/2019
# 1110029623                  1/21/2019
#
# [8 rows x 29 columns]

# %%
# let's search for Webster Butler if maybe other columns have an ID
df[df['ManagerName']=='Webster Butler']
# Out:
#                     Employee_Name  MarriedID  MaritalStatusID  GenderID  \
# EmpID
# 1001417624       Anderson, Carol           0                2         0
# 1110029777          Becker, Scott          0                0         1
# 1111030129      Chang, Donovan  E          0                0         1
# 1306058816        DeGweck,  James          1                1         1
# 1502072511        Ferguson, Susan          1                1         0
# 1008020960           Gilles, Alex          1                1         1
# 1110029602  Harrington, Christie           0                0         0
# 710007401    Kinsella, Kathleen            1                1         0
# 1001138521         Lynch, Lindsay          0                0         0
# 1204033041         Ndzi, Colombui          0                0         1
# 1307060058           Pelech, Emil          0                0         1
# 1405067642        Rivera, Haley            1                1         0
# 807010161          Sewkumar, Nori          0                0         0
# 1405067501     Tavares, Desiree            1                1         0
# 1307060212        Whittier, Scott          0                0         1
# 1101023457     Buccheri, Joseph            0                0         1
# 1402065085        Fancett, Nicole          0                0         0
# 1103024924        Hutter, Rosalie          0                3         0
# 1110029623      Manchester, Robyn          1                1         0
# 1001856521        Oliver, Brooke           1                1         0
# 1011022777       Thibaud, Kenneth          0                4         1
#
#             DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  Termd  \
# EmpID
# 1001417624       5            3                       0    16.00      1
# 1110029777       5            3                       0    17.00      0
# 1111030129       5            3                       0    22.00      0
# 1306058816       5            3                       0    23.50      1
# 1502072511       5            3                       0    20.00      1
# 1008020960       5            2                       1    15.00      1
# 1110029602       5            3                       0    19.75      1
# 710007401        5            3                       0    22.00      1
# 1001138521       5            4                       1    19.00      1
# 1204033041       5            3                       1    18.00      1
# 1307060058       5            2                       0    24.00      1
# 1405067642       5            4                       0    22.00      0
# 807010161        5            3                       0    15.20      0
# 1405067501       5            3                       1    15.00      1
# 1307060212       5            3                       0    23.00      1
# 1101023457       5            3                       0    22.00      0
# 1402065085       5            3                       0    24.00      0
# 1103024924       5            3                       0    28.00      0
# 1110029623       5            3                       0    23.00      0
# 1001856521       5            3                       0    25.00      1
# 1011022777       5            3                       0    23.00      1
#
#             PositionID  ...  DateofHire         Department     ManagerName  \
# EmpID                   ...
# 1001417624          19  ...   7/11/2011  Production         Webster Butler
# 1110029777          19  ...    7/8/2013  Production         Webster Butler
# 1111030129          19  ...    7/8/2013  Production         Webster Butler
# 1306058816          19  ...   5/16/2011  Production         Webster Butler
# 1502072511          19  ...   11/7/2011  Production         Webster Butler
# 1008020960          19  ...    4/2/2012  Production         Webster Butler
# 1110029602          19  ...    1/9/2012  Production         Webster Butler
# 710007401           19  ...   9/26/2011  Production         Webster Butler
# 1001138521          19  ...   11/7/2011  Production         Webster Butler
# 1204033041          19  ...   9/26/2011  Production         Webster Butler
# 1307060058          19  ...   1/10/2011  Production         Webster Butler
# 1405067642          19  ...  11/28/2011  Production         Webster Butler
# 807010161           19  ...   9/30/2013  Production         Webster Butler
# 1405067501          19  ...   4/27/2009  Production         Webster Butler
# 1307060212          19  ...   1/10/2011  Production         Webster Butler
# 1101023457          20  ...   9/29/2014  Production         Webster Butler
# 1402065085          20  ...   2/17/2014  Production         Webster Butler
# 1103024924          20  ...    6/5/2015  Production         Webster Butler
# 1110029623          20  ...   5/11/2016  Production         Webster Butler
# 1001856521          20  ...   5/14/2012  Production         Webster Butler
# 1011022777          20  ...   6/25/2007  Production         Webster Butler
#
#            ManagerID                  RecruitmentSource   PerformanceScore  \
# EmpID
# 1001417624      39.0                      Word of Mouth        Fully Meets
# 1110029777       NaN                           MBTA ads        Fully Meets
# 1111030129       NaN                 Newspager/Magazine        Fully Meets
# 1306058816      39.0                          Billboard        Fully Meets
# 1502072511      39.0  Search Engine - Google Bing Yahoo        Fully Meets
# 1008020960      39.0                 Diversity Job Fair  Needs Improvement
# 1110029602      39.0                        Monster.com        Fully Meets
# 710007401       39.0  Search Engine - Google Bing Yahoo        Fully Meets
# 1001138521      39.0                 Diversity Job Fair            Exceeds
# 1204033041      39.0                 Diversity Job Fair        Fully Meets
# 1307060058      39.0  Search Engine - Google Bing Yahoo  Needs Improvement
# 1405067642       NaN  Search Engine - Google Bing Yahoo            Exceeds
# 807010161        NaN  Search Engine - Google Bing Yahoo        Fully Meets
# 1405067501      39.0                 Diversity Job Fair        Fully Meets
# 1307060212      39.0                 Newspager/Magazine        Fully Meets
# 1101023457       NaN                      Word of Mouth        Fully Meets
# 1402065085       NaN                 Newspager/Magazine        Fully Meets
# 1103024924       NaN                              Other        Fully Meets
# 1110029623       NaN                    Vendor Referral        Fully Meets
# 1001856521      39.0                 Newspager/Magazine        Fully Meets
# 1011022777      39.0             Pay Per Click - Google        Fully Meets
#
#            EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# EmpID
# 1001417624             5.00               4                    0
# 1110029777             1.09               4                    0
# 1111030129             3.80               5                    0
# 1306058816             5.00               4                    0
# 1502072511             3.13               3                    0
# 1008020960             3.97               4                    0
# 1110029602             4.64               4                    0
# 710007401              3.60               5                    0
# 1001138521             5.00               4                    0
# 1204033041             2.61               3                    0
# 1307060058             3.54               5                    0
# 1405067642             4.36               5                    0
# 807010161              5.00               5                    0
# 1405067501             2.52               5                    0
# 1307060212             5.00               5                    0
# 1101023457             3.19               3                    0
# 1402065085             4.00               4                    0
# 1103024924             2.63               3                    0
# 1110029623             5.00               3                    0
# 1001856521             5.00               3                    0
# 1011022777             1.37               4                    0
#
#            LastPerformanceReview_Date
# EmpID
# 1001417624                        NaN
# 1110029777                  1/11/2019
# 1111030129                  1/14/2019
# 1306058816                        NaN
# 1502072511                        NaN
# 1008020960                        NaN
# 1110029602                        NaN
# 710007401                         NaN
# 1001138521                        NaN
# 1204033041                        NaN
# 1307060058                        NaN
# 1405067642                  2/11/2019
# 807010161                   2/21/2019
# 1405067501                        NaN
# 1307060212                        NaN
# 1101023457                   2/1/2019
# 1402065085                   1/7/2019
# 1103024924                  2/14/2019
# 1110029623                  1/21/2019
# 1001856521                        NaN
# 1011022777                        NaN
#
# [21 rows x 29 columns]

# %%
# set ManagerID=39 where it's NaN
df.loc[df['ManagerID'].isnull(), 'ManagerID'] = 39.0
df[df['ManagerName']=='Webster Butler']
# Out:
#                     Employee_Name  MarriedID  MaritalStatusID  GenderID  \
# EmpID
# 1001417624       Anderson, Carol           0                2         0
# 1110029777          Becker, Scott          0                0         1
# 1111030129      Chang, Donovan  E          0                0         1
# 1306058816        DeGweck,  James          1                1         1
# 1502072511        Ferguson, Susan          1                1         0
# 1008020960           Gilles, Alex          1                1         1
# 1110029602  Harrington, Christie           0                0         0
# 710007401    Kinsella, Kathleen            1                1         0
# 1001138521         Lynch, Lindsay          0                0         0
# 1204033041         Ndzi, Colombui          0                0         1
# 1307060058           Pelech, Emil          0                0         1
# 1405067642        Rivera, Haley            1                1         0
# 807010161          Sewkumar, Nori          0                0         0
# 1405067501     Tavares, Desiree            1                1         0
# 1307060212        Whittier, Scott          0                0         1
# 1101023457     Buccheri, Joseph            0                0         1
# 1402065085        Fancett, Nicole          0                0         0
# 1103024924        Hutter, Rosalie          0                3         0
# 1110029623      Manchester, Robyn          1                1         0
# 1001856521        Oliver, Brooke           1                1         0
# 1011022777       Thibaud, Kenneth          0                4         1
#
#             DeptID  PerfScoreID  FromDiversityJobFairID  PayRate  Termd  \
# EmpID
# 1001417624       5            3                       0    16.00      1
# 1110029777       5            3                       0    17.00      0
# 1111030129       5            3                       0    22.00      0
# 1306058816       5            3                       0    23.50      1
# 1502072511       5            3                       0    20.00      1
# 1008020960       5            2                       1    15.00      1
# 1110029602       5            3                       0    19.75      1
# 710007401        5            3                       0    22.00      1
# 1001138521       5            4                       1    19.00      1
# 1204033041       5            3                       1    18.00      1
# 1307060058       5            2                       0    24.00      1
# 1405067642       5            4                       0    22.00      0
# 807010161        5            3                       0    15.20      0
# 1405067501       5            3                       1    15.00      1
# 1307060212       5            3                       0    23.00      1
# 1101023457       5            3                       0    22.00      0
# 1402065085       5            3                       0    24.00      0
# 1103024924       5            3                       0    28.00      0
# 1110029623       5            3                       0    23.00      0
# 1001856521       5            3                       0    25.00      1
# 1011022777       5            3                       0    23.00      1
#
#             PositionID  ...  DateofHire         Department     ManagerName  \
# EmpID                   ...
# 1001417624          19  ...   7/11/2011  Production         Webster Butler
# 1110029777          19  ...    7/8/2013  Production         Webster Butler
# 1111030129          19  ...    7/8/2013  Production         Webster Butler
# 1306058816          19  ...   5/16/2011  Production         Webster Butler
# 1502072511          19  ...   11/7/2011  Production         Webster Butler
# 1008020960          19  ...    4/2/2012  Production         Webster Butler
# 1110029602          19  ...    1/9/2012  Production         Webster Butler
# 710007401           19  ...   9/26/2011  Production         Webster Butler
# 1001138521          19  ...   11/7/2011  Production         Webster Butler
# 1204033041          19  ...   9/26/2011  Production         Webster Butler
# 1307060058          19  ...   1/10/2011  Production         Webster Butler
# 1405067642          19  ...  11/28/2011  Production         Webster Butler
# 807010161           19  ...   9/30/2013  Production         Webster Butler
# 1405067501          19  ...   4/27/2009  Production         Webster Butler
# 1307060212          19  ...   1/10/2011  Production         Webster Butler
# 1101023457          20  ...   9/29/2014  Production         Webster Butler
# 1402065085          20  ...   2/17/2014  Production         Webster Butler
# 1103024924          20  ...    6/5/2015  Production         Webster Butler
# 1110029623          20  ...   5/11/2016  Production         Webster Butler
# 1001856521          20  ...   5/14/2012  Production         Webster Butler
# 1011022777          20  ...   6/25/2007  Production         Webster Butler
#
#            ManagerID                  RecruitmentSource   PerformanceScore  \
# EmpID
# 1001417624      39.0                      Word of Mouth        Fully Meets
# 1110029777      39.0                           MBTA ads        Fully Meets
# 1111030129      39.0                 Newspager/Magazine        Fully Meets
# 1306058816      39.0                          Billboard        Fully Meets
# 1502072511      39.0  Search Engine - Google Bing Yahoo        Fully Meets
# 1008020960      39.0                 Diversity Job Fair  Needs Improvement
# 1110029602      39.0                        Monster.com        Fully Meets
# 710007401       39.0  Search Engine - Google Bing Yahoo        Fully Meets
# 1001138521      39.0                 Diversity Job Fair            Exceeds
# 1204033041      39.0                 Diversity Job Fair        Fully Meets
# 1307060058      39.0  Search Engine - Google Bing Yahoo  Needs Improvement
# 1405067642      39.0  Search Engine - Google Bing Yahoo            Exceeds
# 807010161       39.0  Search Engine - Google Bing Yahoo        Fully Meets
# 1405067501      39.0                 Diversity Job Fair        Fully Meets
# 1307060212      39.0                 Newspager/Magazine        Fully Meets
# 1101023457      39.0                      Word of Mouth        Fully Meets
# 1402065085      39.0                 Newspager/Magazine        Fully Meets
# 1103024924      39.0                              Other        Fully Meets
# 1110029623      39.0                    Vendor Referral        Fully Meets
# 1001856521      39.0                 Newspager/Magazine        Fully Meets
# 1011022777      39.0             Pay Per Click - Google        Fully Meets
#
#            EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# EmpID
# 1001417624             5.00               4                    0
# 1110029777             1.09               4                    0
# 1111030129             3.80               5                    0
# 1306058816             5.00               4                    0
# 1502072511             3.13               3                    0
# 1008020960             3.97               4                    0
# 1110029602             4.64               4                    0
# 710007401              3.60               5                    0
# 1001138521             5.00               4                    0
# 1204033041             2.61               3                    0
# 1307060058             3.54               5                    0
# 1405067642             4.36               5                    0
# 807010161              5.00               5                    0
# 1405067501             2.52               5                    0
# 1307060212             5.00               5                    0
# 1101023457             3.19               3                    0
# 1402065085             4.00               4                    0
# 1103024924             2.63               3                    0
# 1110029623             5.00               3                    0
# 1001856521             5.00               3                    0
# 1011022777             1.37               4                    0
#
#            LastPerformanceReview_Date
# EmpID
# 1001417624                        NaN
# 1110029777                  1/11/2019
# 1111030129                  1/14/2019
# 1306058816                        NaN
# 1502072511                        NaN
# 1008020960                        NaN
# 1110029602                        NaN
# 710007401                         NaN
# 1001138521                        NaN
# 1204033041                        NaN
# 1307060058                        NaN
# 1405067642                  2/11/2019
# 807010161                   2/21/2019
# 1405067501                        NaN
# 1307060212                        NaN
# 1101023457                   2/1/2019
# 1402065085                   1/7/2019
# 1103024924                  2/14/2019
# 1110029623                  1/21/2019
# 1001856521                        NaN
# 1011022777                        NaN
#
# [21 rows x 29 columns]

# %%
# convert MarriedID and other boolean types
df['MarriedID'] = df['MarriedID'].astype(bool)
df['FromDiversityJobFairID'] = df['FromDiversityJobFairID'].astype(bool)
df['Termd'] = df['Termd'].astype(bool)
df['GenderID'] = df['GenderID'].astype(bool)
df.describe()
# Out:
#        MaritalStatusID      DeptID  PerfScoreID     PayRate  PositionID  \
# count       310.000000  310.000000   310.000000  310.000000  310.000000
# mean          0.809677    4.606452     2.983871   31.284806   16.838710
# std           0.944702    1.082349     0.577124   15.383615    6.232272
# min           0.000000    1.000000     1.000000   14.000000    1.000000
# 25%           0.000000    5.000000     3.000000   20.000000   18.000000
# 50%           1.000000    5.000000     3.000000   24.000000   19.000000
# 75%           1.000000    5.000000     3.000000   45.315000   20.000000
# max           4.000000    6.000000     4.000000   80.000000   30.000000
#
#                 Zip   ManagerID  EngagementSurvey  EmpSatisfaction  \
# count    310.000000  310.000000        310.000000       310.000000
# mean    6569.732258   15.209677          3.332097         3.890323
# std    16933.864054    8.876968          1.290590         0.910690
# min     1013.000000    1.000000          1.030000         1.000000
# 25%     1901.250000   10.000000          2.082500         3.000000
# 50%     2132.000000   16.000000          3.470000         4.000000
# 75%     2357.000000   19.750000          4.520000         5.000000
# max    98052.000000   39.000000          5.000000         5.000000
#
#        SpecialProjectsCount
# count            310.000000
# mean               1.209677
# std                2.352009
# min                0.000000
# 25%                0.000000
# 50%                0.000000
# 75%                0.000000
# max                8.000000

# %%
# describe only works for numerical values
# we may inspect the types of the dataframe columns
df.dtypes
# Out:
# Employee_Name                  object
# MarriedID                        bool
# MaritalStatusID                 int64
# GenderID                         bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# Department                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
# Employee_Name is not relevant for prediction and we have the ID for identification
df = df.drop(columns='Employee_Name')
df.dtypes
# Out:
# MarriedID                        bool
# MaritalStatusID                 int64
# GenderID                         bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# MaritalDesc                    object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# Department                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
# prediction library Scikit needs all predictors encoded numerically or booleans
# MaritalDesc is categorical and we have the same information in MaritalStatusID as int
# MarriedID holds a subset of data of MaritalStatusID
# let's drop MaritalDesc and MarriedID
df = df.drop(columns=['MarriedID', 'MaritalDesc'])
df.dtypes
# Out:
# MaritalStatusID                 int64
# GenderID                         bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# Sex                            object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# Department                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
# GenderID isn't a helpful column name for a boolean
# column Sex tells us that GenderID=False is F (female) and True is M (male)
# let's drop Sex and rename GenderID
df = df.drop(columns='Sex')
df = df.rename(columns={'GenderID': 'isMale'})
df.dtypes
# Out:
# MaritalStatusID                 int64
# isMale                           bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# Department                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
# numerical DeptID holds the same information as Department
# let's drop Department
df = df.drop(columns='Department')
df.dtypes
# Out:
# MaritalStatusID                 int64
# isMale                           bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# PerformanceScore               object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
# numerical PerfScoreID holds the same information as PerformanceScore
# let's drop PerformanceScore
df = df.drop(columns='PerformanceScore')
df.dtypes
# Out:
# MaritalStatusID                 int64
# isMale                           bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# PositionID                      int64
# Position                       object
# State                          object
# Zip                             int64
# DOB                            object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
# check Position's values to determine suitability
df["Position"].value_counts()
# Out:
# Production Technician I         136
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                 9
# IT Support                        8
# Data Analyst                      7
# Database Administrator            5
# Network Engineer                  5
# Sr. Network Engineer              5
# BI Developer                      4
# Senior BI Developer               3
# Sales Manager                     3
# Accountant I                      3
# Administrative Assistant          3
# Shared Services Manager           2
# IT Manager - DB                   2
# Sr. Accountant                    2
# Sr. DBA                           2
# Data Architect                    1
# Director of Sales                 1
# Enterprise Architect              1
# President & CEO                   1
# Data Analyst                      1
# IT Manager - Support              1
# BI Director                       1
# Director of Operations            1
# Principal Data Architect          1
# IT Director                       1
# IT Manager - Infra                1
# Software Engineering Manager      1
# CIO                               1
# Name: Position, dtype: int64

# %%
# too many categories with too few entries, so we drop it
# (one could create a new boolean column isProductionTechnician based on this)
# numeric PositionID holds the same information as Position
df = df.drop(columns=['Position', 'PositionID'])
df.dtypes
# Out:
# MaritalStatusID                 int64
# isMale                           bool
# DeptID                          int64
# PerfScoreID                     int64
# FromDiversityJobFairID           bool
# PayRate                       float64
# Termd                            bool
# State                          object
# Zip                             int64
# DOB                            object
# CitizenDesc                    object
# HispanicLatino                 object
# RaceDesc                       object
# DateofHire                     object
# ManagerName                    object
# ManagerID                     float64
# RecruitmentSource              object
# EngagementSurvey              float64
# EmpSatisfaction                 int64
# SpecialProjectsCount            int64
# LastPerformanceReview_Date     object
# dtype: object

# %%
df["State"].value_counts()
# Out:
# col_0  count
# State
# AL         1
# AZ         1
# CA         1
# CO         1
# CT         6
# FL         1
# GA         1
# ID         1
# IN         1
# KY         1
# MA       275
# ME         1
# MT         1
# NC         1
# ND         1
# NH         1
# NV         1
# NY         1
# OH         1
# OR         1
# PA         1
# RI         1
# TN         1
# TX         3
# UT         1
# VA         1
# VT         2
# WA         1

# %%
# too many categories with too few entries
# create a new column isFromMA based on State and drop State
df.loc[df['State']=='MA', 'isFromMA'] = True
df.loc[df['State']!='MA', 'isFromMA'] = False
df = df.drop(columns='State')
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  \
# EmpID
# 1103024456                1   False       1            3
# 1106026572                2    True       1            3
# 1302053333                0    True       1            3
# 1211050782                1   False       1            3
# 1307059817                0   False       1            3
# ...                     ...     ...     ...          ...
# 1411071312                1   False       3            3
# 1108028108                1    True       3            3
# 904013591                 1    True       3            3
# 1308060959                0    True       3            3
# 1301052347                4   False       3            3
#
#             FromDiversityJobFairID  PayRate  Termd   Zip       DOB  \
# EmpID
# 1103024456                    True    28.50  False  1450  11/24/87
# 1106026572                   False    23.00  False  1460  04/26/84
# 1302053333                   False    29.00  False  2703  09/01/86
# 1211050782                   False    21.50   True  2170  09/16/85
# 1307059817                   False    16.56  False  2330  05/19/88
# ...                            ...      ...    ...   ...       ...
# 1411071312                   False    54.10  False  6033  01/18/52
# 1108028108                   False    56.20  False  2169  04/23/86
# 904013591                    False    53.80  False  1545  02/09/83
# 1308060959                   False    53.00  False  6278  09/09/65
# 1301052347                   False    55.20  False  2453  05/02/78
#
#            CitizenDesc  ...                   RaceDesc  DateofHire  \
# EmpID                   ...
# 1103024456  US Citizen  ...  Black or African American  10/27/2008
# 1106026572  US Citizen  ...  Black or African American    1/6/2014
# 1302053333  US Citizen  ...                      White   9/29/2014
# 1211050782  US Citizen  ...                      White   2/16/2015
# 1307059817  US Citizen  ...                      White    5/1/2015
# ...                ...  ...                        ...         ...
# 1411071312  US Citizen  ...                      White  11/10/2014
# 1108028108  US Citizen  ...                      White  11/10/2014
# 904013591   US Citizen  ...                      Asian   6/30/2016
# 1308060959  US Citizen  ...                      White  11/10/2014
# 1301052347  US Citizen  ...                      Asian   3/30/2015
#
#                    ManagerName ManagerID       RecruitmentSource  \
# EmpID
# 1103024456  Brandon R. LeBlanc       1.0      Diversity Job Fair
# 1106026572  Brandon R. LeBlanc       1.0      Website Banner Ads
# 1302053333  Brandon R. LeBlanc       1.0         Internet Search
# 1211050782  Brandon R. LeBlanc       1.0  Pay Per Click - Google
# 1307059817  Brandon R. LeBlanc       1.0      Website Banner Ads
# ...                        ...       ...                     ...
# 1411071312        Peter Monroe       7.0         Vendor Referral
# 1108028108        Peter Monroe       7.0       Employee Referral
# 904013591         Peter Monroe       7.0    On-campus Recruiting
# 1308060959        Peter Monroe       7.0       Employee Referral
# 1301052347        Peter Monroe       7.0       Employee Referral
#
#            EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# EmpID
# 1103024456             2.04                2                     6
# 1106026572             5.00                4                     4
# 1302053333             3.90                5                     5
# 1211050782             3.24                3                     4
# 1307059817             5.00                3                     5
# ...                     ...              ...                   ...
# 1411071312             1.55                5                     8
# 1108028108             4.46                5                     6
# 904013591              3.27                4                     5
# 1308060959             5.00                3                     4
# 1301052347             1.06                4                     8
#
#             LastPerformanceReview_Date isFromMA
# EmpID
# 1103024456                   1/15/2019     True
# 1106026572                   1/17/2019     True
# 1302053333                   1/18/2019     True
# 1211050782                         NaN     True
# 1307059817                   1/15/2019     True
# ...                                ...      ...
# 1411071312                   2/12/2019    False
# 1108028108                    1/7/2019     True
# 904013591                    1/14/2019     True
# 1308060959                    1/2/2019    False
# 1301052347                    2/5/2019     True
#
# [310 rows x 21 columns]

# %%
# let's drop ZIP as well as it would be only helpful within MA
df = df.drop(columns='Zip')
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  \
# EmpID
# 1103024456                1   False       1            3
# 1106026572                2    True       1            3
# 1302053333                0    True       1            3
# 1211050782                1   False       1            3
# 1307059817                0   False       1            3
# ...                     ...     ...     ...          ...
# 1411071312                1   False       3            3
# 1108028108                1    True       3            3
# 904013591                 1    True       3            3
# 1308060959                0    True       3            3
# 1301052347                4   False       3            3
#
#             FromDiversityJobFairID  PayRate  Termd       DOB CitizenDesc  \
# EmpID
# 1103024456                    True    28.50  False  11/24/87  US Citizen
# 1106026572                   False    23.00  False  04/26/84  US Citizen
# 1302053333                   False    29.00  False  09/01/86  US Citizen
# 1211050782                   False    21.50   True  09/16/85  US Citizen
# 1307059817                   False    16.56  False  05/19/88  US Citizen
# ...                            ...      ...    ...       ...         ...
# 1411071312                   False    54.10  False  01/18/52  US Citizen
# 1108028108                   False    56.20  False  04/23/86  US Citizen
# 904013591                    False    53.80  False  02/09/83  US Citizen
# 1308060959                   False    53.00  False  09/09/65  US Citizen
# 1301052347                   False    55.20  False  05/02/78  US Citizen
#
#            HispanicLatino                   RaceDesc  DateofHire  \
# EmpID
# 1103024456             No  Black or African American  10/27/2008
# 1106026572             No  Black or African American    1/6/2014
# 1302053333             No                      White   9/29/2014
# 1211050782             No                      White   2/16/2015
# 1307059817             No                      White    5/1/2015
# ...                   ...                        ...         ...
# 1411071312             No                      White  11/10/2014
# 1108028108             No                      White  11/10/2014
# 904013591              No                      Asian   6/30/2016
# 1308060959             No                      White  11/10/2014
# 1301052347             No                      Asian   3/30/2015
#
#                    ManagerName  ManagerID       RecruitmentSource  \
# EmpID
# 1103024456  Brandon R. LeBlanc        1.0      Diversity Job Fair
# 1106026572  Brandon R. LeBlanc        1.0      Website Banner Ads
# 1302053333  Brandon R. LeBlanc        1.0         Internet Search
# 1211050782  Brandon R. LeBlanc        1.0  Pay Per Click - Google
# 1307059817  Brandon R. LeBlanc        1.0      Website Banner Ads
# ...                        ...        ...                     ...
# 1411071312        Peter Monroe        7.0         Vendor Referral
# 1108028108        Peter Monroe        7.0       Employee Referral
# 904013591         Peter Monroe        7.0    On-campus Recruiting
# 1308060959        Peter Monroe        7.0       Employee Referral
# 1301052347        Peter Monroe        7.0       Employee Referral
#
#             EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# EmpID
# 1103024456              2.04                2                     6
# 1106026572              5.00                4                     4
# 1302053333              3.90                5                     5
# 1211050782              3.24                3                     4
# 1307059817              5.00                3                     5
# ...                      ...              ...                   ...
# 1411071312              1.55                5                     8
# 1108028108              4.46                5                     6
# 904013591               3.27                4                     5
# 1308060959              5.00                3                     4
# 1301052347              1.06                4                     8
#
#            LastPerformanceReview_Date  isFromMA
# EmpID
# 1103024456                  1/15/2019      True
# 1106026572                  1/17/2019      True
# 1302053333                  1/18/2019      True
# 1211050782                        NaN      True
# 1307059817                  1/15/2019      True
# ...                               ...       ...
# 1411071312                  2/12/2019     False
# 1108028108                   1/7/2019      True
# 904013591                   1/14/2019      True
# 1308060959                   1/2/2019     False
# 1301052347                   2/5/2019      True
#
# [310 rows x 20 columns]

# %%
df['DOB'] = pd.to_datetime(df['DOB'])
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  \
# EmpID
# 1103024456                1   False       1            3
# 1106026572                2    True       1            3
# 1302053333                0    True       1            3
# 1211050782                1   False       1            3
# 1307059817                0   False       1            3
# ...                     ...     ...     ...          ...
# 1411071312                1   False       3            3
# 1108028108                1    True       3            3
# 904013591                 1    True       3            3
# 1308060959                0    True       3            3
# 1301052347                4   False       3            3
#
#             FromDiversityJobFairID  PayRate  Termd        DOB CitizenDesc  \
# EmpID
# 1103024456                    True    28.50  False 1987-11-24  US Citizen
# 1106026572                   False    23.00  False 1984-04-26  US Citizen
# 1302053333                   False    29.00  False 1986-09-01  US Citizen
# 1211050782                   False    21.50   True 1985-09-16  US Citizen
# 1307059817                   False    16.56  False 1988-05-19  US Citizen
# ...                            ...      ...    ...        ...         ...
# 1411071312                   False    54.10  False 2052-01-18  US Citizen
# 1108028108                   False    56.20  False 1986-04-23  US Citizen
# 904013591                    False    53.80  False 1983-02-09  US Citizen
# 1308060959                   False    53.00  False 2065-09-09  US Citizen
# 1301052347                   False    55.20  False 1978-05-02  US Citizen
#
#            HispanicLatino                   RaceDesc  DateofHire  \
# EmpID
# 1103024456             No  Black or African American  10/27/2008
# 1106026572             No  Black or African American    1/6/2014
# 1302053333             No                      White   9/29/2014
# 1211050782             No                      White   2/16/2015
# 1307059817             No                      White    5/1/2015
# ...                   ...                        ...         ...
# 1411071312             No                      White  11/10/2014
# 1108028108             No                      White  11/10/2014
# 904013591              No                      Asian   6/30/2016
# 1308060959             No                      White  11/10/2014
# 1301052347             No                      Asian   3/30/2015
#
#                    ManagerName  ManagerID       RecruitmentSource  \
# EmpID
# 1103024456  Brandon R. LeBlanc        1.0      Diversity Job Fair
# 1106026572  Brandon R. LeBlanc        1.0      Website Banner Ads
# 1302053333  Brandon R. LeBlanc        1.0         Internet Search
# 1211050782  Brandon R. LeBlanc        1.0  Pay Per Click - Google
# 1307059817  Brandon R. LeBlanc        1.0      Website Banner Ads
# ...                        ...        ...                     ...
# 1411071312        Peter Monroe        7.0         Vendor Referral
# 1108028108        Peter Monroe        7.0       Employee Referral
# 904013591         Peter Monroe        7.0    On-campus Recruiting
# 1308060959        Peter Monroe        7.0       Employee Referral
# 1301052347        Peter Monroe        7.0       Employee Referral
#
#             EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# EmpID
# 1103024456              2.04                2                     6
# 1106026572              5.00                4                     4
# 1302053333              3.90                5                     5
# 1211050782              3.24                3                     4
# 1307059817              5.00                3                     5
# ...                      ...              ...                   ...
# 1411071312              1.55                5                     8
# 1108028108              4.46                5                     6
# 904013591               3.27                4                     5
# 1308060959              5.00                3                     4
# 1301052347              1.06                4                     8
#
#            LastPerformanceReview_Date  isFromMA
# EmpID
# 1103024456                  1/15/2019      True
# 1106026572                  1/17/2019      True
# 1302053333                  1/18/2019      True
# 1211050782                        NaN      True
# 1307059817                  1/15/2019      True
# ...                               ...       ...
# 1411071312                  2/12/2019     False
# 1108028108                   1/7/2019      True
# 904013591                   1/14/2019      True
# 1308060959                   1/2/2019     False
# 1301052347                   2/5/2019      True
#
# [310 rows x 20 columns]

# %%
# some DOBs are in the future, due to a conversion error
# values 69–99 are mapped to 1969–1999, and values 0–68 are mapped to 2000–2068
from datetime import timedelta, date
future = df['DOB'] > pd.Timestamp(year=2019,month=1,day=1)
df.loc[future, 'DOB'] -= timedelta(days=365.25*100)
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  \
# EmpID
# 1103024456                1   False       1            3
# 1106026572                2    True       1            3
# 1302053333                0    True       1            3
# 1211050782                1   False       1            3
# 1307059817                0   False       1            3
# ...                     ...     ...     ...          ...
# 1411071312                1   False       3            3
# 1108028108                1    True       3            3
# 904013591                 1    True       3            3
# 1308060959                0    True       3            3
# 1301052347                4   False       3            3
#
#             FromDiversityJobFairID  PayRate  Termd        DOB CitizenDesc  \
# EmpID
# 1103024456                    True    28.50  False 1987-11-24  US Citizen
# 1106026572                   False    23.00  False 1984-04-26  US Citizen
# 1302053333                   False    29.00  False 1986-09-01  US Citizen
# 1211050782                   False    21.50   True 1985-09-16  US Citizen
# 1307059817                   False    16.56  False 1988-05-19  US Citizen
# ...                            ...      ...    ...        ...         ...
# 1411071312                   False    54.10  False 1952-01-18  US Citizen
# 1108028108                   False    56.20  False 1986-04-23  US Citizen
# 904013591                    False    53.80  False 1983-02-09  US Citizen
# 1308060959                   False    53.00  False 1965-09-09  US Citizen
# 1301052347                   False    55.20  False 1978-05-02  US Citizen
#
#            HispanicLatino                   RaceDesc  DateofHire  \
# EmpID
# 1103024456             No  Black or African American  10/27/2008
# 1106026572             No  Black or African American    1/6/2014
# 1302053333             No                      White   9/29/2014
# 1211050782             No                      White   2/16/2015
# 1307059817             No                      White    5/1/2015
# ...                   ...                        ...         ...
# 1411071312             No                      White  11/10/2014
# 1108028108             No                      White  11/10/2014
# 904013591              No                      Asian   6/30/2016
# 1308060959             No                      White  11/10/2014
# 1301052347             No                      Asian   3/30/2015
#
#                    ManagerName  ManagerID       RecruitmentSource  \
# EmpID
# 1103024456  Brandon R. LeBlanc        1.0      Diversity Job Fair
# 1106026572  Brandon R. LeBlanc        1.0      Website Banner Ads
# 1302053333  Brandon R. LeBlanc        1.0         Internet Search
# 1211050782  Brandon R. LeBlanc        1.0  Pay Per Click - Google
# 1307059817  Brandon R. LeBlanc        1.0      Website Banner Ads
# ...                        ...        ...                     ...
# 1411071312        Peter Monroe        7.0         Vendor Referral
# 1108028108        Peter Monroe        7.0       Employee Referral
# 904013591         Peter Monroe        7.0    On-campus Recruiting
# 1308060959        Peter Monroe        7.0       Employee Referral
# 1301052347        Peter Monroe        7.0       Employee Referral
#
#             EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  \
# EmpID
# 1103024456              2.04                2                     6
# 1106026572              5.00                4                     4
# 1302053333              3.90                5                     5
# 1211050782              3.24                3                     4
# 1307059817              5.00                3                     5
# ...                      ...              ...                   ...
# 1411071312              1.55                5                     8
# 1108028108              4.46                5                     6
# 904013591               3.27                4                     5
# 1308060959              5.00                3                     4
# 1301052347              1.06                4                     8
#
#            LastPerformanceReview_Date  isFromMA
# EmpID
# 1103024456                  1/15/2019      True
# 1106026572                  1/17/2019      True
# 1302053333                  1/18/2019      True
# 1211050782                        NaN      True
# 1307059817                  1/15/2019      True
# ...                               ...       ...
# 1411071312                  2/12/2019     False
# 1108028108                   1/7/2019      True
# 904013591                   1/14/2019      True
# 1308060959                   1/2/2019     False
# 1301052347                   2/5/2019      True
#
# [310 rows x 20 columns]

# %%
# numerical ManagerID holds the same information as ManagerName
# let's drop ManagerName
df = df.drop(columns='ManagerName')
df.dtypes
# Out:
# MaritalStatusID                        int64
# isMale                                  bool
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                  bool
# PayRate                              float64
# Termd                                   bool
# DOB                           datetime64[ns]
# CitizenDesc                           object
# HispanicLatino                        object
# RaceDesc                              object
# DateofHire                            object
# ManagerID                            float64
# RecruitmentSource                     object
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date            object
# isFromMA                                bool
# dtype: object

# %%
# check distribution and correlation of CitizenDesc
df.groupby(['CitizenDesc', 'Termd']).size().unstack(fill_value=0)
# Out:
# Termd                False  True
# CitizenDesc
# Eligible NonCitizen      7      5
# Non-Citizen              1      3
# US Citizen             199     95

# %%
# only few employees are Non-Citizens but they terminate way more often
# we keep the variable as categorical
df['CitizenDesc'] = df['CitizenDesc'].astype('category')
df.dtypes
# Out:
# MaritalStatusID                        int64
# isMale                                  bool
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                  bool
# PayRate                              float64
# Termd                                   bool
# DOB                           datetime64[ns]
# CitizenDesc                         category
# HispanicLatino                        object
# RaceDesc                              object
# DateofHire                            object
# ManagerID                            float64
# RecruitmentSource                     object
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date            object
# isFromMA                                bool
# dtype: object

# %%
# we remove the "race"-related columns HispanicLatino and RaceDesc
df = df.drop(columns=['HispanicLatino', 'RaceDesc'])
df.dtypes
# Out:
# MaritalStatusID                        int64
# isMale                                  bool
# DeptID                                 int64
# PerfScoreID                            int64
# FromDiversityJobFairID                  bool
# PayRate                              float64
# Termd                                   bool
# DOB                           datetime64[ns]
# CitizenDesc                         category
# DateofHire                            object
# ManagerID                            float64
# RecruitmentSource                     object
# EngagementSurvey                     float64
# EmpSatisfaction                        int64
# SpecialProjectsCount                   int64
# LastPerformanceReview_Date            object
# isFromMA                                bool
# dtype: object

# %%
df['DateofHire'] = pd.to_datetime(df['DateofHire'])
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  \
# EmpID
# 1103024456                1   False       1            3
# 1106026572                2    True       1            3
# 1302053333                0    True       1            3
# 1211050782                1   False       1            3
# 1307059817                0   False       1            3
# ...                     ...     ...     ...          ...
# 1411071312                1   False       3            3
# 1108028108                1    True       3            3
# 904013591                 1    True       3            3
# 1308060959                0    True       3            3
# 1301052347                4   False       3            3
#
#             FromDiversityJobFairID  PayRate  Termd        DOB CitizenDesc  \
# EmpID
# 1103024456                    True    28.50  False 1987-11-24  US Citizen
# 1106026572                   False    23.00  False 1984-04-26  US Citizen
# 1302053333                   False    29.00  False 1986-09-01  US Citizen
# 1211050782                   False    21.50   True 1985-09-16  US Citizen
# 1307059817                   False    16.56  False 1988-05-19  US Citizen
# ...                            ...      ...    ...        ...         ...
# 1411071312                   False    54.10  False 1952-01-18  US Citizen
# 1108028108                   False    56.20  False 1986-04-23  US Citizen
# 904013591                    False    53.80  False 1983-02-09  US Citizen
# 1308060959                   False    53.00  False 1965-09-09  US Citizen
# 1301052347                   False    55.20  False 1978-05-02  US Citizen
#
#            DateofHire  ManagerID       RecruitmentSource  EngagementSurvey  \
# EmpID
# 1103024456 2008-10-27        1.0      Diversity Job Fair              2.04
# 1106026572 2014-01-06        1.0      Website Banner Ads              5.00
# 1302053333 2014-09-29        1.0         Internet Search              3.90
# 1211050782 2015-02-16        1.0  Pay Per Click - Google              3.24
# 1307059817 2015-05-01        1.0      Website Banner Ads              5.00
# ...               ...        ...                     ...               ...
# 1411071312 2014-11-10        7.0         Vendor Referral              1.55
# 1108028108 2014-11-10        7.0       Employee Referral              4.46
# 904013591  2016-06-30        7.0    On-campus Recruiting              3.27
# 1308060959 2014-11-10        7.0       Employee Referral              5.00
# 1301052347 2015-03-30        7.0       Employee Referral              1.06
#
#             EmpSatisfaction  SpecialProjectsCount LastPerformanceReview_Date  \
# EmpID
# 1103024456                2                     6                  1/15/2019
# 1106026572                4                     4                  1/17/2019
# 1302053333                5                     5                  1/18/2019
# 1211050782                3                     4                        NaN
# 1307059817                3                     5                  1/15/2019
# ...                     ...                   ...                        ...
# 1411071312                5                     8                  2/12/2019
# 1108028108                5                     6                   1/7/2019
# 904013591                 4                     5                  1/14/2019
# 1308060959                3                     4                   1/2/2019
# 1301052347                4                     8                   2/5/2019
#
#             isFromMA
# EmpID
# 1103024456      True
# 1106026572      True
# 1302053333      True
# 1211050782      True
# 1307059817      True
# ...              ...
# 1411071312     False
# 1108028108      True
# 904013591       True
# 1308060959     False
# 1301052347      True
#
# [310 rows x 17 columns]

# %%
df.groupby(['RecruitmentSource', 'Termd']).size().unstack(fill_value=0)
# Out:
# Termd                                   False  True
# RecruitmentSource
# Billboard                                  11      5
# Careerbuilder                               1      0
# Company Intranet - Partner                  0      1
# Diversity Job Fair                         13     16
# Employee Referral                          27      4
# Glassdoor                                   8      6
# Indeed                                      8      0
# Information Session                         3      1
# Internet Search                             4      2
# MBTA ads                                   13      4
# Monster.com                                13     11
# Newspager/Magazine                         13      5
# On-campus Recruiting                       11      1
# On-line Web application                     0      1
# Other                                       6      3
# Pay Per Click                               0      1
# Pay Per Click - Google                     17      4
# Professional Society                       17      3
# Search Engine - Google Bing Yahoo          10     15
# Social Networks - Facebook Twitter etc      3      8
# Vendor Referral                            11      4
# Website Banner Ads                         12      1
# Word of Mouth                               6      7

# %%
# many different observations but we'll use them as categories
# we can drop FromDiversityJobFairID as the information is included in here
df = df.drop(columns='FromDiversityJobFairID')
df['RecruitmentSource'] = df['RecruitmentSource'].astype('category')
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  PayRate  Termd  \
# EmpID
# 1103024456                1   False       1            3    28.50  False
# 1106026572                2    True       1            3    23.00  False
# 1302053333                0    True       1            3    29.00  False
# 1211050782                1   False       1            3    21.50   True
# 1307059817                0   False       1            3    16.56  False
# ...                     ...     ...     ...          ...      ...    ...
# 1411071312                1   False       3            3    54.10  False
# 1108028108                1    True       3            3    56.20  False
# 904013591                 1    True       3            3    53.80  False
# 1308060959                0    True       3            3    53.00  False
# 1301052347                4   False       3            3    55.20  False
#
#                   DOB CitizenDesc DateofHire  ManagerID  \
# EmpID
# 1103024456 1987-11-24  US Citizen 2008-10-27        1.0
# 1106026572 1984-04-26  US Citizen 2014-01-06        1.0
# 1302053333 1986-09-01  US Citizen 2014-09-29        1.0
# 1211050782 1985-09-16  US Citizen 2015-02-16        1.0
# 1307059817 1988-05-19  US Citizen 2015-05-01        1.0
# ...               ...         ...        ...        ...
# 1411071312 1952-01-18  US Citizen 2014-11-10        7.0
# 1108028108 1986-04-23  US Citizen 2014-11-10        7.0
# 904013591  1983-02-09  US Citizen 2016-06-30        7.0
# 1308060959 1965-09-09  US Citizen 2014-11-10        7.0
# 1301052347 1978-05-02  US Citizen 2015-03-30        7.0
#
#                  RecruitmentSource  EngagementSurvey  EmpSatisfaction  \
# EmpID
# 1103024456      Diversity Job Fair              2.04                2
# 1106026572      Website Banner Ads              5.00                4
# 1302053333         Internet Search              3.90                5
# 1211050782  Pay Per Click - Google              3.24                3
# 1307059817      Website Banner Ads              5.00                3
# ...                            ...               ...              ...
# 1411071312         Vendor Referral              1.55                5
# 1108028108       Employee Referral              4.46                5
# 904013591     On-campus Recruiting              3.27                4
# 1308060959       Employee Referral              5.00                3
# 1301052347       Employee Referral              1.06                4
#
#             SpecialProjectsCount LastPerformanceReview_Date  isFromMA
# EmpID
# 1103024456                     6                  1/15/2019      True
# 1106026572                     4                  1/17/2019      True
# 1302053333                     5                  1/18/2019      True
# 1211050782                     4                        NaN      True
# 1307059817                     5                  1/15/2019      True
# ...                          ...                        ...       ...
# 1411071312                     8                  2/12/2019     False
# 1108028108                     6                   1/7/2019      True
# 904013591                      5                  1/14/2019      True
# 1308060959                     4                   1/2/2019     False
# 1301052347                     8                   2/5/2019      True
#
# [310 rows x 16 columns]

# %%
# LastPerformanceReview_Date has NaN values (no review)
# check how many NaNs and correlation to Termd
df.groupby(['LastPerformanceReview_Date', 'Termd']).size().unstack(fill_value=0)
# Out:
# LastPerformanceReview_Date  False  True
# Termd
# False                         207      0
# True                            0    103

# %%
# all non-terminated employees had an interview (in 2019), all terminated employees didn't have one
# two possible interpretations:
# 1) Do performance review to keep employees from terminating!
# 2) All reviews happened 2019. Let's assume the company started reviews 2019 after so many people terminated.
# Following 2), we drop the column
df = df.drop(columns='LastPerformanceReview_Date')
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  PayRate  Termd  \
# EmpID
# 1103024456                1   False       1            3    28.50  False
# 1106026572                2    True       1            3    23.00  False
# 1302053333                0    True       1            3    29.00  False
# 1211050782                1   False       1            3    21.50   True
# 1307059817                0   False       1            3    16.56  False
# ...                     ...     ...     ...          ...      ...    ...
# 1411071312                1   False       3            3    54.10  False
# 1108028108                1    True       3            3    56.20  False
# 904013591                 1    True       3            3    53.80  False
# 1308060959                0    True       3            3    53.00  False
# 1301052347                4   False       3            3    55.20  False
#
#                   DOB CitizenDesc DateofHire  ManagerID  \
# EmpID
# 1103024456 1987-11-24  US Citizen 2008-10-27        1.0
# 1106026572 1984-04-26  US Citizen 2014-01-06        1.0
# 1302053333 1986-09-01  US Citizen 2014-09-29        1.0
# 1211050782 1985-09-16  US Citizen 2015-02-16        1.0
# 1307059817 1988-05-19  US Citizen 2015-05-01        1.0
# ...               ...         ...        ...        ...
# 1411071312 1952-01-18  US Citizen 2014-11-10        7.0
# 1108028108 1986-04-23  US Citizen 2014-11-10        7.0
# 904013591  1983-02-09  US Citizen 2016-06-30        7.0
# 1308060959 1965-09-09  US Citizen 2014-11-10        7.0
# 1301052347 1978-05-02  US Citizen 2015-03-30        7.0
#
#                  RecruitmentSource  EngagementSurvey  EmpSatisfaction  \
# EmpID
# 1103024456      Diversity Job Fair              2.04                2
# 1106026572      Website Banner Ads              5.00                4
# 1302053333         Internet Search              3.90                5
# 1211050782  Pay Per Click - Google              3.24                3
# 1307059817      Website Banner Ads              5.00                3
# ...                            ...               ...              ...
# 1411071312         Vendor Referral              1.55                5
# 1108028108       Employee Referral              4.46                5
# 904013591     On-campus Recruiting              3.27                4
# 1308060959       Employee Referral              5.00                3
# 1301052347       Employee Referral              1.06                4
#
#             SpecialProjectsCount  isFromMA
# EmpID
# 1103024456                     6      True
# 1106026572                     4      True
# 1302053333                     5      True
# 1211050782                     4      True
# 1307059817                     5      True
# ...                          ...       ...
# 1411071312                     8     False
# 1108028108                     6      True
# 904013591                      5      True
# 1308060959                     4     False
# 1301052347                     8      True
#
# [310 rows x 15 columns]

# %% [markdown]
# ## Data Exploration

# %%
# using DOB in modelling is hard
# let's create the numerical age and drop the date
df['age'] = pd.to_datetime("now") - df['DOB']
df['age'] = df['age'] / np.timedelta64(1,'Y')
df['age'] = df['age'].astype('int32')
df = df.drop(columns='DOB')
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  PayRate  Termd  \
# EmpID
# 1103024456                1   False       1            3    28.50  False
# 1106026572                2    True       1            3    23.00  False
# 1302053333                0    True       1            3    29.00  False
# 1211050782                1   False       1            3    21.50   True
# 1307059817                0   False       1            3    16.56  False
# ...                     ...     ...     ...          ...      ...    ...
# 1411071312                1   False       3            3    54.10  False
# 1108028108                1    True       3            3    56.20  False
# 904013591                 1    True       3            3    53.80  False
# 1308060959                0    True       3            3    53.00  False
# 1301052347                4   False       3            3    55.20  False
#
#            CitizenDesc DateofHire  ManagerID       RecruitmentSource  \
# EmpID
# 1103024456  US Citizen 2008-10-27        1.0      Diversity Job Fair
# 1106026572  US Citizen 2014-01-06        1.0      Website Banner Ads
# 1302053333  US Citizen 2014-09-29        1.0         Internet Search
# 1211050782  US Citizen 2015-02-16        1.0  Pay Per Click - Google
# 1307059817  US Citizen 2015-05-01        1.0      Website Banner Ads
# ...                ...        ...        ...                     ...
# 1411071312  US Citizen 2014-11-10        7.0         Vendor Referral
# 1108028108  US Citizen 2014-11-10        7.0       Employee Referral
# 904013591   US Citizen 2016-06-30        7.0    On-campus Recruiting
# 1308060959  US Citizen 2014-11-10        7.0       Employee Referral
# 1301052347  US Citizen 2015-03-30        7.0       Employee Referral
#
#             EngagementSurvey  EmpSatisfaction  SpecialProjectsCount  isFromMA  \
# EmpID
# 1103024456              2.04                2                     6      True
# 1106026572              5.00                4                     4      True
# 1302053333              3.90                5                     5      True
# 1211050782              3.24                3                     4      True
# 1307059817              5.00                3                     5      True
# ...                      ...              ...                   ...       ...
# 1411071312              1.55                5                     8     False
# 1108028108              4.46                5                     6      True
# 904013591               3.27                4                     5      True
# 1308060959              5.00                3                     4     False
# 1301052347              1.06                4                     8      True
#
#             age
# EmpID
# 1103024456   32
# 1106026572   35
# 1302053333   33
# 1211050782   34
# 1307059817   31
# ...         ...
# 1411071312   68
# 1108028108   33
# 904013591    36
# 1308060959   54
# 1301052347   41
#
# [310 rows x 15 columns]

# %%
# let's do the same for DateofHire
df['tenure'] = pd.to_datetime("now") - df['DateofHire']
df['tenure'] = df['tenure'] / np.timedelta64(1,'Y')
df['tenure'] = df['tenure'].astype('int32')
df = df.drop(columns='DateofHire')
df
# Out:
#             MaritalStatusID  isMale  DeptID  PerfScoreID  PayRate  Termd  \
# EmpID
# 1103024456                1   False       1            3    28.50  False
# 1106026572                2    True       1            3    23.00  False
# 1302053333                0    True       1            3    29.00  False
# 1211050782                1   False       1            3    21.50   True
# 1307059817                0   False       1            3    16.56  False
# ...                     ...     ...     ...          ...      ...    ...
# 1411071312                1   False       3            3    54.10  False
# 1108028108                1    True       3            3    56.20  False
# 904013591                 1    True       3            3    53.80  False
# 1308060959                0    True       3            3    53.00  False
# 1301052347                4   False       3            3    55.20  False
#
#            CitizenDesc  ManagerID       RecruitmentSource  EngagementSurvey  \
# EmpID
# 1103024456  US Citizen        1.0      Diversity Job Fair              2.04
# 1106026572  US Citizen        1.0      Website Banner Ads              5.00
# 1302053333  US Citizen        1.0         Internet Search              3.90
# 1211050782  US Citizen        1.0  Pay Per Click - Google              3.24
# 1307059817  US Citizen        1.0      Website Banner Ads              5.00
# ...                ...        ...                     ...               ...
# 1411071312  US Citizen        7.0         Vendor Referral              1.55
# 1108028108  US Citizen        7.0       Employee Referral              4.46
# 904013591   US Citizen        7.0    On-campus Recruiting              3.27
# 1308060959  US Citizen        7.0       Employee Referral              5.00
# 1301052347  US Citizen        7.0       Employee Referral              1.06
#
#             EmpSatisfaction  SpecialProjectsCount  isFromMA  age  tenure
# EmpID
# 1103024456                2                     6      True   32      11
# 1106026572                4                     4      True   35       6
# 1302053333                5                     5      True   33       5
# 1211050782                3                     4      True   34       4
# 1307059817                3                     5      True   31       4
# ...                     ...                   ...       ...  ...     ...
# 1411071312                5                     8     False   68       5
# 1108028108                5                     6      True   33       5
# 904013591                 4                     5      True   36       3
# 1308060959                3                     4     False   54       5
# 1301052347                4                     8      True   41       4
#
# [310 rows x 15 columns]

# %%
# let's start plotting
# we need to import a new library
import matplotlib as plt
# this makes the plots appear inline in the notebook
# %matplotlib inline

# %%
# histograms show the distribution of data
df['age'].hist()

# %%
df['tenure'].hist()

# %%
df['PayRate'].hist()

# %%
# PayRate has outliers, so we log-transform our data to nullify their effects
df['PayRateLog'] = np.log(df['PayRate'])
df['PayRateLog'].hist()

# %%
# boxplots show outliers, mean and 25%/75% percentiles
df.boxplot(column=['age', 'tenure', 'PayRate'])

# %%
df.boxplot(column=['PerfScoreID', 'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount', 'PayRateLog'])

# %%
# show a correlation matrix for correlations between all variables
# we expect the predictors with the highest correlation with Termd to play an important role in prediction
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(1)
# Out:
# <style  type="text/css" >
#     #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col1 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col2 {
#             background-color:  #cedaeb;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col3 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col5 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col6 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col7 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col8 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col9 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col10 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col11 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col12 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow0_col13 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col0 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col2 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col3 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col4 {
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col5 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col6 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col8 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col9 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col10 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col11 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col12 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow1_col13 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col0 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col1 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col3 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col5 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col6 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col7 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col8 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col10 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col11 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col12 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow2_col13 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col0 {
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col1 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col2 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col4 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col5 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col6 {
#             background-color:  #a2c1ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col7 {
#             background-color:  #5673e0;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col8 {
#             background-color:  #b1cbfc;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col9 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col10 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col11 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col12 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow3_col13 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow4_col1 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow4_col2 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_4ff48a3e_47f1_11ea_87f6_eda3f9eacf5erow4_col3 {
#             background-color:  #5b7ae5;
#             colo

# %% [markdown]
# ## Build a Prediction Model

# %%
# we use Scikit-Learn for modelling
# Scikit requires all variables to be numerical, so we need to encode the categorical columns
from sklearn.preprocessing import LabelEncoder
df.dtypes
# Out:
# MaritalStatusID            int64
# isMale                      bool
# DeptID                     int64
# PerfScoreID                int64
# PayRate                  float64
# Termd                       bool
# CitizenDesc             category
# ManagerID                float64
# RecruitmentSource       category
# EngagementSurvey         float64
# EmpSatisfaction            int64
# SpecialProjectsCount       int64
# isFromMA                    bool
# age                        int32
# tenure                     int32
# PayRateLog               float64
# dtype: object

# %%
categoricals = ['CitizenDesc', 'RecruitmentSource']
encoder = LabelEncoder()
for i in categoricals:
    df[i] = encoder.fit_transform(df[i])
df.dtypes
# Out:
# MaritalStatusID           int64
# isMale                     bool
# DeptID                    int64
# PerfScoreID               int64
# PayRate                 float64
# Termd                      bool
# CitizenDesc               int64
# ManagerID               float64
# RecruitmentSource         int64
# EngagementSurvey        float64
# EmpSatisfaction           int64
# SpecialProjectsCount      int64
# isFromMA                   bool
# age                       int32
# tenure                    int32
# PayRateLog              float64
# dtype: object

# %%
# What's the easiest prediction model you may think of?
# Just use the modus of Termd and you get a baseline accuracy.
len(df[df['Termd']==False]) / len(df)
# Out:
# 0.667741935483871

# %%
# import models from scikit learn
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn import metrics

# %%
# select the variables that we want to use to predict Termd
predictors = ['MaritalStatusID', 'tenure']

# fit a LogisticRegresssion as a first try
# this is called regression although we do classification (sorting entries into Termd: True/False)
model = LogisticRegression(solver='lbfgs').fit(df[predictors], df['Termd'])
# make prediction on training set
prediction = model.predict(df[predictors])

accuracy = metrics.accuracy_score(prediction, df['Termd'])
print("Accuracy: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy: 69.677%

# %%
# select the variables that we want to use to predict Termd
predictors = ['MaritalStatusID', 'tenure', 'PayRateLog', 'RecruitmentSource']

# fit a decision tree
model = DecisionTreeClassifier().fit(df[predictors], df['Termd'])
# make prediction on training set
prediction = model.predict(df[predictors])

accuracy = metrics.accuracy_score(prediction, df['Termd'])
print("Accuracy: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy: 99.355%

# %%
# sounds too good to be true, doesn't it?
# for now, we have used all data for training, testing and validation
# let's split by 50/25/25%
train = df[0:150]
test = df[151:225]
validate = df[226:]

# %%
# select the variables that we want to use to predict Termd
predictors = ['MaritalStatusID', 'tenure', 'PayRateLog', 'RecruitmentSource']

# fit a decision tree again - with training data
model = DecisionTreeClassifier().fit(train[predictors], train['Termd'])
# make prediction on training set
prediction = model.predict(train[predictors])

accuracy = metrics.accuracy_score(prediction, train['Termd'])
print("Accuracy on training data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on training data: 100.000%

# %%
# make prediction on test set
prediction = model.predict(test[predictors])

accuracy = metrics.accuracy_score(prediction, test['Termd'])
print("Accuracy on test data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on test data: 60.811%

# %%
# the accuracy on training data is 100% - the model fits perfectly to the data
# the accuracy on test data is worse than our baseline model - the trained model is overfitted on the training data
# could be changed by trying other (fewer) predictors or changing the model parameters

# fit a decision tree again - with training data and adjusted model parameters
model = DecisionTreeClassifier(max_depth=5, max_features='auto').fit(train[predictors], train['Termd'])
# make prediction on training set
prediction = model.predict(train[predictors])

accuracy = metrics.accuracy_score(prediction, train['Termd'])
print("Accuracy on training data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on training data: 88.000%

# %%
# make prediction on test set
prediction = model.predict(test[predictors])

accuracy = metrics.accuracy_score(prediction, test['Termd'])
print("Accuracy on test data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on test data: 78.378%

# %%
df.dtypes
# Out:
# MaritalStatusID           int64
# isMale                     bool
# DeptID                    int64
# PerfScoreID               int64
# PayRate                 float64
# Termd                      bool
# CitizenDesc               int64
# ManagerID               float64
# RecruitmentSource         int64
# EngagementSurvey        float64
# EmpSatisfaction           int64
# SpecialProjectsCount      int64
# isFromMA                   bool
# age                       int32
# tenure                    int32
# PayRateLog              float64
# dtype: object

# %%
# more realistic but let's try a more sophisticated algorithm
# random forests are randomly generated decision trees that are combined into one
# different runs yield different results (due to randomness)

# use all variables for random forest to predict Termd
predictors = ['MaritalStatusID', 'isMale', 'DeptID', 'PerfScoreID', 'CitizenDesc', 'ManagerID', 'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount', 'isFromMA', 'age', 'tenure', 'PayRateLog', 'RecruitmentSource']

# fit a random forest (n randomized decision trees)
model = RandomForestClassifier(n_estimators=100).fit(train[predictors], train['Termd'])
# make prediction on training set
prediction = model.predict(train[predictors])

accuracy = metrics.accuracy_score(prediction, train['Termd'])
print("Accuracy on training data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on training data: 100.000%

# %%
# make prediction on test set
prediction = model.predict(test[predictors])

accuracy = metrics.accuracy_score(prediction, test['Termd'])
print("Accuracy on test data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on test data: 55.405%

# %%
# again the model is overfitted, let's find out which predictors to exclude
# random forests determine the feature importances
importance = pd.Series(model.feature_importances_, index=predictors).sort_values(ascending=False)
print(importance)
# Out:
# PayRateLog              0.144218
# tenure                  0.133608
# EngagementSurvey        0.129056
# age                     0.125176
# ManagerID               0.099072
# RecruitmentSource       0.087212
# EmpSatisfaction         0.074988
# MaritalStatusID         0.050777
# SpecialProjectsCount    0.040892
# PerfScoreID             0.036622
# DeptID                  0.027465
# isMale                  0.026471
# isFromMA                0.015436
# CitizenDesc             0.009008
# dtype: float64

# %%
# use most important variables for random forest to predict Termd
predictors = ['PayRateLog', 'tenure', 'EngagementSurvey']

# fit a random forest (n randomized decision trees)
model = RandomForestClassifier(n_estimators=100).fit(train[predictors], train['Termd'])
# make prediction on training set
prediction = model.predict(train[predictors])

accuracy = metrics.accuracy_score(prediction, train['Termd'])
print("Accuracy on training data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on training data: 99.333%

# %%
# make prediction on test set
prediction = model.predict(test[predictors])

accuracy = metrics.accuracy_score(prediction, test['Termd'])
print("Accuracy on test data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on test data: 67.568%

# %%
# random forests can also be used to just get the feature importance and then use the predictors with other algorithms

# fit a random forest (n randomized decision trees) with adjusted model parameters
model = RandomForestClassifier(n_estimators=100, max_depth=5, warm_start=True).fit(train[predictors], train['Termd'])
# make prediction on training set
prediction = model.predict(train[predictors])

accuracy = metrics.accuracy_score(prediction, train['Termd'])
print("Accuracy on training data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on training data: 86.667%

# %%
# make prediction on test set
prediction = model.predict(test[predictors])

accuracy = metrics.accuracy_score(prediction, test['Termd'])
print("Accuracy on test data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on test data: 67.568%

# %%
# let's evaluate the model with our validation data set
prediction = model.predict(validate[predictors])
accuracy = metrics.accuracy_score(prediction, validate['Termd'])
print("Accuracy on validation data: %s" % "{0:.3%}".format(accuracy))
# Out:
# Accuracy on validation data: 66.667%

# %% [markdown]
# ## Closing Remarks
# * Using more complex models doesn't necessary yield better results.
# * Feature engineering, feature selection and model parameter tuning can take long time.
# * Sometimes, the data is just insufficient or does not correlate with the target variable at all, so no decent model may be trained.
# * Different runs with models using randomness may yield different results.
# * There are way more models than the three we discussed, try others.
#
# Our model could now be used to predict which employee is likely to terminate next. Then, the employer could schedule a feedback meeting, grant a special project, increase the wage…
